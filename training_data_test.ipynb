# %%
import numpy as np
from agent_code.training_data.memory import ReplayMemory

# %%
from collections import namedtuple

# first we extract all information from the memory
ActionWithEvent = namedtuple("Transition", ("game_state", "state", "action", "score", "events", "round_reward", "discounted_reward"))
# then we change it into network_input, action, discounted_reward
Datapoint = namedtuple("Datapoint", ("network_input", "action", "discounted_reward"))

# %%
replay = ReplayMemory()

# %%
replay.load_from_file('agent_code/training_data/training_data.pt')

# %%
len(replay)
# Out:
# 383781

# %%
memories = replay.get()

# %%
import events as e

# %%
def get_score(memory):
    return memory.state["self"][1]

def get_round(memory):
    return memory.state["round"]

def get_step(memory):
    return memory.state["step"]

def get_reward_from_events(events):
    rewards = {
        e.CRATE_DESTROYED: 0.1,
        e.KILLED_SELF: -1,
        e.GOT_KILLED: -0.9,
        e.INVALID_ACTION: -0.1,
    }
    reward = sum([rewards.get(event, 0.) for event in events])
    return round(reward, 2)

# %%
get_score(memories[106])
# Out:
# 1

# %%
last_score = 0
for memory in memories:
    score = get_score(memory) 
    diff = score - last_score
    reward = diff + get_reward_from_events(memory.reward)
    last_score = score
    if reward != 0:
        print(get_step(memory), get_round(memory), get_score(memory), reward, get_reward_from_events(memory.reward), memory.reward)

    if not memory.next_state:
        print(get_round(memory))
        last_score = 0
# Out:
# 7 1 0 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 15 1 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 26 1 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 27 1 0 -0.1 -0.1 ['INVALID_ACTION']
# 34 1 0 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 56 1 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 69 1 0 0.1 0.1 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 70 1 0 -0.1 -0.1 ['INVALID_ACTION']
# 94 1 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 106 1 1 1.0 0.0 ['MOVED_RIGHT']
# 111 1 1 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 118 1 2 1.0 0.0 ['MOVED_DOWN']
# 126 1 2 -0.1 -0.1 ['INVALID_ACTION']
# 145 1 2 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 152 1 2 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 158 1 3 1.0 0.0 ['MOVED_LEFT']
# 163 1 3 -0.1 -0.1 ['INVALID_ACTION']
# 168 1 3 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 243 1 3 -0.1 -0.1 ['INVALID_ACTION']
# 244 1 3 -0.1 -0.1 ['INVALID_ACTION']
# 245 1 3 -1.8 -1.8 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 1
# 6 2 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 2 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 2 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 23 2 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 29 2 1 1.0 0.0 ['MOVED_UP']
# 35 2 1 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 49 2 1 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 64 2 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 74 2 1 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 82 2 1 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 97 2 1 -0.1 -0.1 ['INVALID_ACTION']
# 109 2 2 1.0 0.0 ['MOVED_DOWN']
# 138 2 2 -0.1 -0.1 ['INVALID_ACTION']
# 144 2 2 -0.1 -0.1 ['INVALID_ACTION']
# 146 2 2 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 156 2 2 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 169 2 3 1.0 0.0 ['MOVED_DOWN']
# 176 2 3 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 236 2 3 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 250 2 3 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 258 2 3 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 260 2 3 -0.1 -0.1 ['INVALID_ACTION']
# 348 2 3 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 394 2 3 -0.1 -0.1 ['INVALID_ACTION']
# 2
# 6 3 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 3 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 3 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 23 3 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 35 3 0 0.4 0.4 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 3 1 1.0 0.0 ['MOVED_LEFT']
# 49 3 1 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 59 3 1 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 63 3 2 1.0 0.0 ['MOVED_LEFT', 'OPPONENT_ELIMINATED']
# 74 3 2 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 90 3 2 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 93 3 2 -0.1 -0.1 ['INVALID_ACTION']
# 104 3 2 -0.1 -0.1 ['INVALID_ACTION']
# 116 3 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 135 3 2 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 142 3 2 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 144 3 3 1.0 0.0 ['MOVED_UP', 'COIN_COLLECTED']
# 145 3 4 1.0 0.0 ['BOMB_DROPPED']
# 149 3 4 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 157 3 4 -0.1 -0.1 ['INVALID_ACTION']
# 165 3 4 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 173 3 4 -0.1 -0.1 ['INVALID_ACTION']
# 210 3 4 -0.1 -0.1 ['INVALID_ACTION']
# 227 3 4 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 231 3 5 1.0 0.0 ['MOVED_UP']
# 233 3 5 -0.1 -0.1 ['INVALID_ACTION']
# 248 3 5 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 250 3 5 -0.1 -0.1 ['INVALID_ACTION']
# 325 3 5 -0.1 -0.1 ['INVALID_ACTION']
# 329 3 5 -0.1 -0.1 ['INVALID_ACTION']
# 340 3 5 -0.1 -0.1 ['INVALID_ACTION']
# 362 3 5 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 394 3 5 -0.1 -0.1 ['INVALID_ACTION']
# 3
# 6 4 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 4 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 4 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 4 0 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 4 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 4 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 44 4 0 -0.1 -0.1 ['INVALID_ACTION']
# 51 4 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 62 4 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 74 4 0 -1.4 -1.4 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 4
# 6 5 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 5 0 0.4 0.4 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 5 0 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 5 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 32 5 0 -0.1 -0.1 ['INVALID_ACTION']
# 39 5 0 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 41 5 1 1.0 0.0 ['MOVED_LEFT']
# 50 5 1 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 79 5 6 5.0 0.0 ['MOVED_UP']
# 91 5 6 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 105 5 6 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 109 5 7 1.0 0.0 ['MOVED_RIGHT']
# 133 5 7 -0.1 -0.1 ['INVALID_ACTION']
# 138 5 7 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 152 5 7 -0.1 -0.1 ['INVALID_ACTION']
# 159 5 7 -0.1 -0.1 ['INVALID_ACTION']
# 164 5 7 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 165 5 7 -0.1 -0.1 ['INVALID_ACTION']
# 186 5 7 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 190 5 7 -0.1 -0.1 ['INVALID_ACTION']
# 288 5 7 -0.1 -0.1 ['INVALID_ACTION']
# 315 5 8 1.0 0.0 ['MOVED_RIGHT']
# 332 5 8 -0.1 -0.1 ['INVALID_ACTION']
# 360 5 8 -0.1 -0.1 ['INVALID_ACTION']
# 361 5 8 -1.9 -1.9 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 5
# 6 6 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 14 6 0 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 17 6 1 1.0 0.0 ['MOVED_DOWN']
# 23 6 1 0.6 0.6 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 30 6 2 1.0 0.0 ['MOVED_DOWN']
# 35 6 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 42 6 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 48 6 3 1.0 0.0 ['MOVED_UP']
# 57 6 3 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 64 6 3 0.1 0.1 ['MOVED_UP', 'COIN_COLLECTED', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 65 6 4 1.0 0.0 ['MOVED_DOWN']
# 68 6 5 1.0 0.0 ['MOVED_DOWN']
# 80 6 5 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 89 6 5 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 98 6 5 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 118 6 5 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 131 6 5 -0.1 -0.1 ['INVALID_ACTION']
# 174 6 5 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 186 6 6 1.0 0.0 ['MOVED_LEFT']
# 193 6 6 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 217 6 6 -0.1 -0.1 ['INVALID_ACTION']
# 222 6 6 -0.1 -0.1 ['INVALID_ACTION']
# 241 6 6 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 252 6 6 -0.1 -0.1 ['INVALID_ACTION']
# 253 6 6 -0.1 -0.1 ['INVALID_ACTION']
# 254 6 6 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 6
# 6 7 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 7 0 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 7 0 0.6 0.6 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 28 7 1 1.0 0.0 ['MOVED_UP']
# 41 7 1 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 46 7 2 1.0 0.0 ['MOVED_UP']
# 48 7 3 1.0 0.0 ['MOVED_RIGHT']
# 54 7 3 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 65 7 3 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 68 7 3 -0.1 -0.1 ['INVALID_ACTION']
# 74 7 3 -0.1 -0.1 ['INVALID_ACTION']
# 89 7 3 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 91 7 3 -0.1 -0.1 ['INVALID_ACTION']
# 95 7 3 -0.1 -0.1 ['INVALID_ACTION']
# 96 7 3 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'OPPONENT_ELIMINATED', 'GOT_KILLED']
# 7
# 6 8 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 8 0 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 18 8 1 1.0 0.0 ['MOVED_RIGHT']
# 25 8 1 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 33 8 1 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 34 8 1 -0.1 -0.1 ['INVALID_ACTION']
# 41 8 1 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 45 8 2 1.0 0.0 ['MOVED_DOWN']
# 50 8 2 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 55 8 3 1.0 0.0 ['MOVED_DOWN']
# 61 8 3 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 81 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 93 8 3 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 106 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 115 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 116 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 118 8 3 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 119 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 129 8 3 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 133 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 142 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 143 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 189 8 3 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 190 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 223 8 3 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 225 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 269 8 3 -0.1 -0.1 ['INVALID_ACTION']
# 8
# 6 9 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 9 0 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 17 9 1 1.0 0.0 ['MOVED_RIGHT']
# 22 9 1 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 9 1 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 39 9 1 0.6 0.6 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 51 9 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 52 9 1 -0.1 -0.1 ['INVALID_ACTION']
# 59 9 1 0.4 0.4 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 69 9 1 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 80 9 6 5.0 0.0 ['MOVED_RIGHT']
# 91 9 6 -0.1 -0.1 ['INVALID_ACTION']
# 103 9 6 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 115 9 6 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 116 9 6 -0.1 -0.1 ['INVALID_ACTION']
# 124 9 7 1.0 0.0 ['MOVED_RIGHT']
# 132 9 7 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 140 9 7 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'COIN_FOUND']
# 146 9 8 1.0 0.0 ['MOVED_DOWN']
# 149 9 8 -0.1 -0.1 ['INVALID_ACTION']
# 152 9 9 1.0 0.0 ['MOVED_UP']
# 155 9 9 -0.1 -0.1 ['INVALID_ACTION']
# 173 9 9 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 182 9 9 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 250 9 9 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 254 9 9 -0.1 -0.1 ['INVALID_ACTION']
# 281 9 9 -0.1 -0.1 ['INVALID_ACTION']
# 9
# 6 10 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 10 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 10 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 10 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 29 10 0 0.6 0.6 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 32 10 1 1.0 0.0 ['MOVED_LEFT']
# 39 10 1 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 48 10 1 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 54 10 2 1.0 0.0 ['MOVED_LEFT']
# 59 10 2 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 60 10 2 -0.1 -0.1 ['INVALID_ACTION']
# 65 10 3 1.0 0.0 ['MOVED_DOWN']
# 69 10 4 1.0 0.0 ['MOVED_UP']
# 71 10 4 -0.1 -0.1 ['INVALID_ACTION']
# 153 10 4 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 160 10 4 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 168 10 5 1.0 0.0 ['MOVED_UP']
# 175 10 5 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 182 10 5 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 189 10 5 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 200 10 5 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 207 10 5 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 220 10 5 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 237 10 5 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 244 10 5 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 251 10 5 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 268 10 5 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 10
# 6 11 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 11 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 11 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 11 0 0.6 0.6 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 35 11 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 49 11 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 62 11 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 70 11 0 0.3 0.3 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 71 11 0 -0.1 -0.1 ['INVALID_ACTION']
# 93 11 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 95 11 0 -0.1 -0.1 ['INVALID_ACTION']
# 115 11 0 -0.1 -0.1 ['INVALID_ACTION']
# 117 11 0 -0.1 -0.1 ['INVALID_ACTION']
# 118 11 0 -1.0 -1.0 ['INVALID_ACTION', 'GOT_KILLED']
# 11
# 6 12 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 13 12 0 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 19 12 1 1.0 0.0 ['MOVED_UP']
# 28 12 1 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 52 12 2 1.0 0.0 ['BOMB_DROPPED']
# 56 12 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 64 12 2 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_OPPONENT', 'OPPONENT_ELIMINATED']
# 65 12 7 4.9 -0.1 ['INVALID_ACTION']
# 72 12 7 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 84 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 117 12 7 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 135 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 136 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 138 12 7 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 145 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 159 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 179 12 7 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 187 12 7 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 220 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 234 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 257 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 267 12 7 -0.1 -0.1 ['INVALID_ACTION']
# 272 12 7 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 289 12 7 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 332 12 7 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 343 12 7 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 354 12 7 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 12
# 6 13 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 13 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 13 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 13 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 32 13 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 33 13 0 -0.1 -0.1 ['INVALID_ACTION']
# 40 13 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 53 13 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 61 13 0 -0.1 -0.1 ['INVALID_ACTION']
# 64 13 0 0.3 0.3 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 65 13 0 -0.1 -0.1 ['INVALID_ACTION']
# 69 13 1 1.0 0.0 ['MOVED_RIGHT']
# 100 13 1 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 122 13 2 1.0 0.0 ['MOVED_DOWN']
# 127 13 2 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 131 13 3 1.0 0.0 ['MOVED_RIGHT']
# 138 13 3 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 147 13 3 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 156 13 3 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 163 13 3 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 170 13 3 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 177 13 3 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 186 13 3 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 195 13 3 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 214 13 3 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 13
# 6 14 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 14 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 14 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 14 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 32 14 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 14 0 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 53 14 0 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 65 14 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 66 14 0 -0.1 -0.1 ['INVALID_ACTION']
# 71 14 1 1.0 0.0 ['BOMB_DROPPED']
# 75 14 1 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 81 14 2 1.0 0.0 ['MOVED_DOWN']
# 108 14 2 -0.1 -0.1 ['INVALID_ACTION']
# 110 14 2 -0.1 -0.1 ['INVALID_ACTION']
# 111 14 2 -1.5 -1.5 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 14
# 6 15 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 15 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 15 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 15 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 15 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 41 15 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 60 15 1 1.0 0.0 ['MOVED_RIGHT']
# 66 15 1 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 76 15 1 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 89 15 1 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 99 15 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 112 15 1 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 118 15 1 -0.1 -0.1 ['INVALID_ACTION']
# 119 15 1 -0.1 -0.1 ['INVALID_ACTION', 'OPPONENT_ELIMINATED']
# 120 15 1 -1.8 -1.8 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 15
# 6 16 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 16 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 16 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 16 0 0.7 0.7 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 34 16 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 45 16 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 52 16 0 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 75 16 1 1.0 0.0 ['MOVED_RIGHT']
# 78 16 2 1.0 0.0 ['MOVED_DOWN']
# 84 16 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 101 16 3 1.0 0.0 ['BOMB_DROPPED']
# 105 16 3 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 160 16 3 -0.1 -0.1 ['INVALID_ACTION']
# 201 16 3 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 210 16 3 -0.1 -0.1 ['INVALID_ACTION']
# 211 16 3 -0.1 -0.1 ['INVALID_ACTION']
# 212 16 3 -1.9 -1.9 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 16
# 6 17 0 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 14 17 0 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 21 17 0 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 25 17 1 1.0 0.0 ['MOVED_UP']
# 31 17 1 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 32 17 1 -0.1 -0.1 ['INVALID_ACTION']
# 39 17 1 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 51 17 1 -0.1 -0.1 ['INVALID_ACTION']
# 54 17 1 -0.1 -0.1 ['INVALID_ACTION']
# 64 17 1 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 78 17 1 -0.1 -0.1 ['INVALID_ACTION']
# 102 17 1 -0.1 -0.1 ['INVALID_ACTION']
# 104 17 1 -0.1 -0.1 ['INVALID_ACTION']
# 113 17 2 1.0 0.0 ['MOVED_LEFT']
# 118 17 2 0.3 0.3 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 119 17 2 -0.1 -0.1 ['INVALID_ACTION']
# 140 17 2 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 146 17 3 1.0 0.0 ['MOVED_UP']
# 185 17 3 -0.1 -0.1 ['INVALID_ACTION']
# 195 17 3 -0.1 -0.1 ['INVALID_ACTION']
# 197 17 3 -0.1 -0.1 ['INVALID_ACTION']
# 232 17 3 -0.1 -0.1 ['INVALID_ACTION']
# 246 17 3 -0.1 -0.1 ['INVALID_ACTION']
# 258 17 4 1.0 0.0 ['MOVED_RIGHT']
# 286 17 4 -0.1 -0.1 ['INVALID_ACTION']
# 333 17 4 -0.1 -0.1 ['INVALID_ACTION']
# 355 17 4 -0.1 -0.1 ['INVALID_ACTION']
# 368 17 4 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 17
# 6 18 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 13 18 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 18 18 1 1.0 0.0 ['MOVED_DOWN']
# 26 18 1 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 39 18 1 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 57 18 1 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 71 18 1 0.4 0.4 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 72 18 1 -0.1 -0.1 ['INVALID_ACTION']
# 73 18 1 -1.0 -1.0 ['INVALID_ACTION', 'GOT_KILLED']
# 18
# 6 19 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 7 19 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 19 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 16 19 1 1.0 0.0 ['MOVED_RIGHT']
# 22 19 1 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 19 1 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 34 19 1 -0.1 -0.1 ['INVALID_ACTION']
# 39 19 1 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 42 19 1 -0.1 -0.1 ['INVALID_ACTION']
# 65 19 1 -0.1 -0.1 ['INVALID_ACTION']
# 81 19 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'OPPONENT_ELIMINATED']
# 84 19 1 -0.1 -0.1 ['INVALID_ACTION']
# 93 19 2 1.0 0.0 ['MOVED_DOWN']
# 118 19 2 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 124 19 3 1.0 0.0 ['MOVED_RIGHT']
# 173 19 3 -0.1 -0.1 ['INVALID_ACTION']
# 178 19 3 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 186 19 3 -0.1 -0.1 ['INVALID_ACTION']
# 192 19 8 5.0 0.0 ['MOVED_RIGHT']
# 205 19 8 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 206 19 8 -0.1 -0.1 ['INVALID_ACTION']
# 219 19 8 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 221 19 8 -0.1 -0.1 ['INVALID_ACTION']
# 239 19 8 0.1 0.1 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 244 19 8 -0.1 -0.1 ['INVALID_ACTION']
# 271 19 8 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 303 19 8 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 309 19 8 -0.1 -0.1 ['INVALID_ACTION']
# 322 19 8 -0.1 -0.1 ['INVALID_ACTION']
# 328 19 8 -0.1 -0.1 ['INVALID_ACTION']
# 356 19 8 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 357 19 8 -0.1 -0.1 ['INVALID_ACTION']
# 19
# 6 20 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 20 0 0.5 0.5 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 20 0 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 20 0 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 40 20 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 49 20 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 60 20 0 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 84 20 0 -0.1 -0.1 ['INVALID_ACTION']
# 101 20 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 108 20 1 1.0 0.0 ['MOVED_LEFT']
# 120 20 1 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 142 20 1 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 153 20 1 0.1 0.1 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 154 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 172 20 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 191 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 208 20 1 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 209 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 240 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 285 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 312 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 324 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 348 20 1 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 349 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 367 20 1 -0.1 -0.1 ['INVALID_ACTION']
# 20
# 6 21 0 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 7 21 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 21 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 21 0 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 21 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 38 21 1 1.0 0.0 ['MOVED_RIGHT']
# 43 21 1 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 66 21 1 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 76 21 1 0.4 0.4 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 83 21 1 -1.8 -1.8 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'KILLED_SELF', 'GOT_KILLED']
# 21
# 6 22 0 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 7 22 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 22 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 22 0 0.5 0.5 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 22 0 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 40 22 0 0.7 0.7 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 52 22 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 60 22 0 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 64 22 1 1.0 0.0 ['BOMB_DROPPED']
# 68 22 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 85 22 1 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 93 22 2 1.0 0.0 ['MOVED_DOWN']
# 98 22 2 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 108 22 2 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 126 22 2 -0.1 -0.1 ['INVALID_ACTION']
# 127 22 2 -0.1 -0.1 ['INVALID_ACTION']
# 139 22 2 -1.8 -1.8 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 22
# 6 23 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 23 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 23 0 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 21 23 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 33 23 0 0.8 0.8 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 45 23 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 52 23 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 57 23 0 -0.1 -0.1 ['INVALID_ACTION']
# 67 23 0 0.3 0.3 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 68 23 0 -0.1 -0.1 ['INVALID_ACTION']
# 75 23 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 86 23 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 91 23 1 1.0 0.0 ['MOVED_LEFT']
# 100 23 1 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 119 23 1 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 128 23 1 -0.1 -0.1 ['INVALID_ACTION']
# 133 23 1 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 142 23 1 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 148 23 2 1.0 0.0 ['MOVED_RIGHT']
# 157 23 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 171 23 2 -0.1 -0.1 ['INVALID_ACTION']
# 202 23 2 -0.1 -0.1 ['INVALID_ACTION']
# 291 23 2 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 331 23 2 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 377 23 2 -0.1 -0.1 ['INVALID_ACTION']
# 386 23 2 -0.1 -0.1 ['INVALID_ACTION']
# 23
# 6 24 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 24 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 24 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 24 0 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 32 24 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 45 24 0 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 53 24 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 80 24 0 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 86 24 1 1.0 0.0 ['MOVED_LEFT']
# 88 24 2 1.0 0.0 ['MOVED_RIGHT']
# 95 24 3 1.0 0.0 ['MOVED_RIGHT']
# 98 24 4 1.0 0.0 ['MOVED_DOWN']
# 103 24 4 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 110 24 4 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 137 24 4 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 149 24 4 -0.1 -0.1 ['INVALID_ACTION']
# 215 24 4 -0.1 -0.1 ['INVALID_ACTION']
# 221 24 4 -0.1 -0.1 ['INVALID_ACTION']
# 222 24 4 -1.0 -1.0 ['INVALID_ACTION', 'GOT_KILLED']
# 24
# 7 25 0 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 15 25 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 25 25 0 -0.1 -0.1 ['INVALID_ACTION']
# 32 25 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 41 25 0 -0.1 -0.1 ['INVALID_ACTION']
# 44 25 0 -1.3 -1.3 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 25
# 6 26 0 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 13 26 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 19 26 1 1.0 0.0 ['MOVED_DOWN']
# 25 26 1 0.6 0.6 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 41 26 1 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 42 26 1 -0.1 -0.1 ['INVALID_ACTION']
# 49 26 1 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 55 26 2 1.0 0.0 ['BOMB_DROPPED']
# 59 26 2 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 65 26 2 -0.1 -0.1 ['INVALID_ACTION']
# 74 26 3 1.0 0.0 ['MOVED_RIGHT']
# 89 26 3 -0.1 -0.1 ['INVALID_ACTION']
# 103 26 3 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 108 26 4 1.0 0.0 ['MOVED_RIGHT']
# 113 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 128 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 135 26 4 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 149 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 166 26 4 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 184 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 204 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 208 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 222 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 272 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 283 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 288 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 307 26 4 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 356 26 4 -0.1 -0.1 ['INVALID_ACTION']
# 359 26 4 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 26
# 6 27 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 27 0 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 27 0 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 27 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 27 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 51 27 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 59 27 0 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 73 27 0 -0.1 -0.1 ['INVALID_ACTION']
# 137 27 0 -0.1 -0.1 ['INVALID_ACTION']
# 138 27 0 -0.1 -0.1 ['INVALID_ACTION']
# 139 27 0 -0.1 -0.1 ['INVALID_ACTION']
# 140 27 0 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 27
# 6 28 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 14 28 0 0.5 0.5 ['MOVED_DOWN', 'COIN_COLLECTED', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 15 28 1 1.0 0.0 ['MOVED_DOWN']
# 21 28 1 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 29 28 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 30 28 1 -0.1 -0.1 ['INVALID_ACTION']
# 37 28 1 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 45 28 1 0.6 0.6 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 53 28 1 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 61 28 1 0.7 0.7 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 67 28 2 1.0 0.0 ['BOMB_DROPPED']
# 76 28 2 -0.1 -0.1 ['INVALID_ACTION']
# 77 28 2 -0.1 -0.1 ['INVALID_ACTION']
# 78 28 2 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 28
# 6 29 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 7 29 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 29 0 0.2 0.2 ['MOVED_UP', 'COIN_COLLECTED', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 15 29 1 1.0 0.0 ['MOVED_UP']
# 22 29 1 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 29 1 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 29 1 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 50 29 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 53 29 2 1.0 0.0 ['MOVED_RIGHT']
# 57 29 2 -0.1 -0.1 ['INVALID_ACTION']
# 69 29 2 -0.1 -0.1 ['INVALID_ACTION']
# 74 29 2 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 86 29 2 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 95 29 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 97 29 2 -0.1 -0.1 ['INVALID_ACTION']
# 99 29 2 -0.1 -0.1 ['INVALID_ACTION']
# 100 29 2 -0.1 -0.1 ['INVALID_ACTION']
# 101 29 2 -0.1 -0.1 ['INVALID_ACTION']
# 102 29 2 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 29
# 6 30 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 30 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 30 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 30 0 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 31 30 0 0.5 0.5 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 30 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 57 30 0 0.6 0.6 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 65 30 1 1.0 0.0 ['MOVED_LEFT']
# 70 30 1 -0.1 -0.1 ['INVALID_ACTION']
# 73 30 1 -1.8 -1.8 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 30
# 6 31 0 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 7 31 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 31 1 1.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 31 1 0.5 0.5 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 23 31 1 -0.1 -0.1 ['INVALID_ACTION']
# 30 31 1 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 36 31 2 1.0 0.0 ['MOVED_RIGHT']
# 47 31 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 56 31 2 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 60 31 3 1.0 0.0 ['MOVED_LEFT']
# 65 31 3 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 76 31 3 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 88 31 3 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 97 31 3 0.5 0.5 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 110 31 3 0.7 0.7 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 114 31 4 1.0 0.0 ['MOVED_RIGHT']
# 148 31 4 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 164 31 9 5.0 0.0 ['MOVED_DOWN']
# 195 31 9 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 227 31 9 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 233 31 10 1.0 0.0 ['MOVED_DOWN']
# 240 31 10 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 313 31 10 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 328 31 10 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 338 31 10 -0.1 -0.1 ['INVALID_ACTION']
# 372 31 10 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 385 31 10 -0.1 -0.1 ['INVALID_ACTION']
# 386 31 10 -0.1 -0.1 ['INVALID_ACTION']
# 387 31 10 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 31
# 6 32 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 32 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 32 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 23 32 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 30 32 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 32 0 -0.1 -0.1 ['INVALID_ACTION']
# 38 32 0 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 44 32 1 1.0 0.0 ['MOVED_UP']
# 51 32 1 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 63 32 1 0.5 0.5 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 75 32 1 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 82 32 1 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 83 32 1 -0.1 -0.1 ['INVALID_ACTION']
# 90 32 1 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 101 32 1 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 106 32 1 -0.1 -0.1 ['INVALID_ACTION']
# 107 32 1 -0.1 -0.1 ['INVALID_ACTION']
# ...
# 41 1691 0 -0.1 -0.1 ['INVALID_ACTION']
# 48 1691 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 50 1691 1 1.0 0.0 ['MOVED_RIGHT']
# 57 1691 1 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 68 1691 1 -0.1 -0.1 ['INVALID_ACTION']
# 69 1691 1 -0.1 -0.1 ['INVALID_ACTION']
# 71 1691 1 -1.5 -1.5 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 1691
# 6 1692 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 1692 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 1692 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 22 1692 0 0.5 0.5 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 23 1692 0 -0.1 -0.1 ['INVALID_ACTION']
# 30 1692 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 38 1692 0 0.4 0.4 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 46 1692 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 48 1692 0 -0.1 -0.1 ['INVALID_ACTION']
# 53 1692 0 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 61 1692 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 79 1692 0 -0.1 -0.1 ['INVALID_ACTION']
# 94 1692 1 1.0 0.0 ['MOVED_RIGHT']
# 96 1692 2 1.0 0.0 ['BOMB_DROPPED']
# 108 1692 3 1.0 0.0 ['BOMB_DROPPED']
# 113 1692 3 -0.1 -0.1 ['INVALID_ACTION']
# 120 1692 3 -0.1 -0.1 ['INVALID_ACTION']
# 196 1692 3 -0.1 -0.1 ['INVALID_ACTION']
# 227 1692 3 -0.1 -0.1 ['INVALID_ACTION']
# 249 1692 3 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 273 1692 3 -0.1 -0.1 ['INVALID_ACTION']
# 313 1692 3 -0.1 -0.1 ['INVALID_ACTION']
# 346 1692 3 -0.1 -0.1 ['INVALID_ACTION']
# 358 1692 3 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 1692
# 6 1693 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 7 1693 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 1693 0 0.2 0.2 ['MOVED_RIGHT', 'COIN_COLLECTED', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 15 1693 1 1.0 0.0 ['MOVED_RIGHT']
# 21 1693 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 1693 1 -0.1 -0.1 ['INVALID_ACTION']
# 29 1693 1 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 36 1693 1 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 47 1693 1 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 57 1693 1 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 65 1693 1 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 79 1693 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 81 1693 1 -0.1 -0.1 ['INVALID_ACTION']
# 107 1693 1 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 1693
# 6 1694 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 1694 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 1694 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 1694 0 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 33 1694 0 0.8 0.8 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 39 1694 1 1.0 0.0 ['MOVED_RIGHT']
# 45 1694 2 1.0 0.0 ['MOVED_LEFT']
# 51 1694 2 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 64 1694 2 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'OPPONENT_ELIMINATED']
# 114 1694 2 -0.1 -0.1 ['INVALID_ACTION']
# 115 1694 2 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 116 1694 2 -0.1 -0.1 ['INVALID_ACTION']
# 159 1694 2 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 197 1694 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 208 1694 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 217 1694 2 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 226 1694 2 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 235 1694 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 244 1694 2 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 257 1694 2 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 1694
# 6 1695 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 1695 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 1695 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 1695 0 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 1695 0 0.4 0.4 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 1695 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 60 1695 1 1.0 0.0 ['MOVED_DOWN']
# 65 1695 1 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 74 1695 1 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 79 1695 2 1.0 0.0 ['MOVED_DOWN']
# 91 1695 2 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 92 1695 2 -0.1 -0.1 ['INVALID_ACTION']
# 96 1695 3 1.0 0.0 ['BOMB_DROPPED']
# 100 1695 3 0.1 0.1 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 101 1695 3 -0.1 -0.1 ['INVALID_ACTION']
# 107 1695 3 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 133 1695 3 -0.1 -0.1 ['INVALID_ACTION']
# 147 1695 3 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'KILLED_OPPONENT', 'OPPONENT_ELIMINATED']
# 148 1695 8 5.0 0.0 ['MOVED_DOWN']
# 149 1695 8 -0.1 -0.1 ['INVALID_ACTION']
# 166 1695 8 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 179 1695 8 -0.1 -0.1 ['INVALID_ACTION']
# 196 1695 8 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 198 1695 8 -0.1 -0.1 ['INVALID_ACTION']
# 206 1695 8 -0.1 -0.1 ['INVALID_ACTION']
# 212 1695 8 -0.1 -0.1 ['INVALID_ACTION']
# 239 1695 9 1.0 0.0 ['MOVED_DOWN']
# 257 1695 9 -0.1 -0.1 ['INVALID_ACTION']
# 270 1695 9 -0.1 -0.1 ['INVALID_ACTION']
# 317 1695 9 -0.1 -0.1 ['INVALID_ACTION']
# 334 1695 9 -0.1 -0.1 ['INVALID_ACTION']
# 350 1695 9 -0.1 -0.1 ['INVALID_ACTION']
# 375 1695 9 -0.1 -0.1 ['INVALID_ACTION']
# 1695
# 6 1696 0 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 1696 0 0.5 0.5 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 21 1696 0 0.5 0.5 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 26 1696 1 1.0 0.0 ['MOVED_UP']
# 33 1696 1 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 45 1696 1 0.6 0.6 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 51 1696 2 1.0 0.0 ['MOVED_UP']
# 59 1696 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 74 1696 2 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 82 1696 2 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 90 1696 2 -0.1 -0.1 ['INVALID_ACTION']
# 105 1696 2 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'KILLED_OPPONENT', 'OPPONENT_ELIMINATED']
# 106 1696 7 5.0 0.0 ['MOVED_RIGHT']
# 118 1696 7 -0.1 -0.1 ['INVALID_ACTION']
# 119 1696 7 -0.1 -0.1 ['INVALID_ACTION']
# 132 1696 7 0.3 0.3 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 142 1696 7 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 152 1696 7 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 156 1696 7 -0.1 -0.1 ['INVALID_ACTION']
# 162 1696 7 -0.1 -0.1 ['INVALID_ACTION']
# 172 1696 7 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 217 1696 7 -0.1 -0.1 ['INVALID_ACTION']
# 255 1696 7 -0.1 -0.1 ['INVALID_ACTION']
# 308 1696 7 -0.1 -0.1 ['INVALID_ACTION']
# 379 1696 7 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 1696
# 6 1697 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 1697 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 1697 0 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 22 1697 0 0.4 0.4 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 1697 0 0.6 0.6 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 43 1697 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 50 1697 0 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 51 1697 0 -0.1 -0.1 ['INVALID_ACTION']
# 58 1697 0 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 60 1697 1 1.0 0.0 ['MOVED_LEFT']
# 64 1697 2 1.0 0.0 ['MOVED_RIGHT']
# 69 1697 2 0.2 0.2 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 72 1697 3 1.0 0.0 ['MOVED_LEFT']
# 80 1697 4 1.0 0.0 ['MOVED_UP']
# 85 1697 4 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 89 1697 4 -0.1 -0.1 ['INVALID_ACTION']
# 95 1697 4 -0.1 -0.1 ['INVALID_ACTION']
# 106 1697 9 5.0 0.0 ['MOVED_LEFT']
# 141 1697 10 1.0 0.0 ['MOVED_UP']
# 146 1697 10 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 148 1697 10 -0.1 -0.1 ['INVALID_ACTION']
# 152 1697 10 -0.1 -0.1 ['INVALID_ACTION']
# 153 1697 10 -2.0 -2.0 ['INVALID_ACTION', 'BOMB_EXPLODED', 'KILLED_SELF', 'GOT_KILLED']
# 1697
# 6 1698 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 1698 0 0.6 0.6 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 23 1698 0 0.4 0.4 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 35 1698 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 43 1698 0 0.8 0.8 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 51 1698 0 0.1 0.1 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 62 1698 0 0.4 0.4 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 70 1698 0 0.6 0.6 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 76 1698 1 1.0 0.0 ['MOVED_UP']
# 86 1698 2 1.0 0.0 ['BOMB_DROPPED']
# 90 1698 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 122 1698 2 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 129 1698 2 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 138 1698 2 0.4 0.4 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 147 1698 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 154 1698 2 0.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 158 1698 3 1.0 0.0 ['MOVED_LEFT']
# 171 1698 3 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 180 1698 3 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 186 1698 4 1.0 0.0 ['MOVED_LEFT']
# 195 1698 4 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 206 1698 4 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 1698
# 6 1699 0 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 7 1699 0 -0.1 -0.1 ['INVALID_ACTION']
# 14 1699 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND']
# 22 1699 0 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 30 1699 1 1.1 0.1 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 37 1699 1 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED']
# 43 1699 2 1.0 0.0 ['MOVED_UP']
# 51 1699 2 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 65 1699 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 66 1699 2 -0.1 -0.1 ['INVALID_ACTION']
# 77 1699 2 0.3 0.3 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 83 1699 2 -0.1 -0.1 ['INVALID_ACTION']
# 84 1699 2 -0.1 -0.1 ['INVALID_ACTION']
# 85 1699 2 -1.8 -1.8 ['INVALID_ACTION', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'KILLED_SELF', 'GOT_KILLED']
# 1699
# 6 1700 0 0.2 0.2 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 14 1700 0 0.6 0.6 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 21 1700 0 0.5 0.5 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 31 1700 0 0.3 0.3 ['MOVED_UP', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 32 1700 0 -0.1 -0.1 ['INVALID_ACTION']
# 39 1700 0 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 47 1700 0 0.9 0.9 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'COIN_FOUND', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 54 1700 1 1.0 0.0 ['MOVED_UP']
# 59 1700 1 0.2 0.2 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 68 1700 2 1.0 0.0 ['MOVED_DOWN']
# 74 1700 2 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 93 1700 2 0.4 0.4 ['MOVED_LEFT', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 105 1700 2 0.6 0.6 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 122 1700 2 0.3 0.3 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 157 1700 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 166 1700 2 -0.1 -0.1 ['INVALID_ACTION']
# 206 1700 2 0.2 0.2 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED', 'CRATE_DESTROYED']
# 213 1700 2 -0.1 -0.1 ['INVALID_ACTION', 'BOMB_EXPLODED']
# 225 1700 2 -0.1 -0.1 ['INVALID_ACTION']
# 273 1700 2 0.1 0.1 ['MOVED_DOWN', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 287 1700 2 -0.1 -0.1 ['INVALID_ACTION']
# 322 1700 2 0.1 0.1 ['MOVED_RIGHT', 'BOMB_EXPLODED', 'CRATE_DESTROYED']
# 366 1700 2 -0.1 -0.1 ['INVALID_ACTION']
# 1700

# %%
memories[0].reward
# Out:
# ['MOVED_DOWN']

# %%
current_round = -1
start_indexes = []
for idx, memory in enumerate(memories):
    if memory.state["round"] != current_round:
        start_indexes.append(idx)
        current_round = memory.state["round"]

# %%
memories.reverse()

# %%
memories[0].state["round"]

# %%
# discount factor reduces the importance of future rewards
# after 10 steps the reward is only 50% of the original reward
discount_factor = 0.93
print(discount_factor ** 10)
# score normalization
# score should be between -1 and 1, since player kills normally give 5 score and coins 1, we normalize by dividing by 5
# we will have to restrict the score to be between -1 and 1
# additionally, since multiple rewards can be given at the same time, and the discounted score from the future is added to the current score, we need to divide by an additional factor
# additional factor is 2 so that the score maxes out if you get 2 kills at once
score_reduction_factor = 1 / (5 * 2)
print(5 * score_reduction_factor * discount_factor + 1 * score_reduction_factor * discount_factor**2 + 1 * score_reduction_factor * discount_factor**3)
# Out:
# 0.4839823071792934
# 0.6319257

# %%
score_increases = {}
for idx, memory in enumerate(memories):
    if idx + 1 >= len(memories):
        break
    if get_score(memories[idx]) > get_score(memories[idx + 1]):
        score_increases[len(memories) - idx - 1] = get_score(memories[idx]) - get_score(memories[idx + 1])

# %%
memories.reverse()

# %%
memories[0].state["step"]
# Out:
# 1

# %%
get_score(memories[382307])
# Out:
# 8

# %%
score_increases
# Out:
# {383447: 1,
#  383433: 1,
#  383337: 1,
#  383324: 1,
#  383269: 1,
#  383241: 1,
#  383169: 1,
#  383159: 1,
#  383071: 1,
#  383036: 5,
#  383010: 1,
#  383002: 1,
#  382994: 1,
#  382990: 1,
#  382652: 5,
#  382597: 1,
#  382572: 1,
#  382398: 1,
#  382307: 5,
#  382255: 1,
#  382238: 1,
#  382219: 1,
#  381942: 1,
#  381936: 1,
#  381805: 1,
#  381497: 1,
#  381485: 1,
#  381483: 1,
#  381368: 1,
#  381015: 1,
#  381012: 5,
#  380989: 1,
#  380988: 1,
#  380942: 1,
#  380907: 1,
#  380780: 5,
#  380754: 1,
#  380302: 1,
#  380232: 1,
#  380017: 1,
#  380014: 1,
#  379903: 1,
#  379814: 5,
#  379782: 5,
#  379769: 1,
#  379546: 1,
#  379235: 1,
#  378938: 5,
#  378810: 1,
#  378763: 1,
#  378653: 1,
#  378600: 1,
#  378401: 1,
#  378376: 1,
#  378256: 1,
#  378176: 1,
#  377539: 5,
#  377462: 1,
#  377257: 1,
#  377170: 5,
#  377063: 1,
#  376743: 1,
#  376610: 1,
#  376570: 1,
#  376556: 1,
#  376528: 5,
#  376344: 5,
#  376289: 1,
#  375936: 1,
#  375908: 5,
#  375896: 1,
#  375882: 1,
#  375822: 1,
#  375712: 1,
#  375691: 1,
#  375644: 1,
#  375418: 1,
#  375001: 5,
#  374864: 1,
#  374841: 1,
#  374562: 1,
#  374533: 5,
#  374455: 1,
#  374443: 1,
#  374370: 1,
#  374177: 1,
#  374155: 1,
#  374137: 1,
#  373984: 5,
#  373823: 1,
#  373811: 1,
#  373784: 1,
#  373763: 1,
#  373736: 1,
#  373558: 1,
#  373435: 1,
#  373384: 1,
#  373118: 5,
#  373001: 1,
#  372936: 1,
#  372871: 1,
#  372769: 1,
#  372762: 5,
#  372742: 1,
#  372667: 1,
#  372338: 1,
#  372297: 1,
#  372296: 5,
#  372276: 1,
#  371889: 1,
#  371871: 1,
#  371830: 1,
#  371798: 1,
#  371654: 1,
#  371368: 1,
#  371335: 1,
#  371305: 1,
#  371179: 1,
#  371129: 1,
#  371071: 5,
#  371012: 1,
#  370979: 1,
#  370586: 1,
#  370572: 1,
#  370538: 1,
#  370527: 1,
#  370446: 1,
#  370407: 1,
#  370398: 1,
#  370364: 1,
#  370208: 1,
#  370033: 1,
#  370018: 1,
#  369974: 1,
#  369818: 1,
#  369802: 1,
#  369772: 1,
#  369509: 1,
#  369208: 5,
#  369162: 1,
#  369106: 1,
#  368861: 1,
#  368860: 1,
#  368696: 1,
#  368648: 1,
#  368638: 1,
#  368604: 1,
#  368231: 1,
#  368165: 1,
#  368155: 1,
#  368150: 1,
#  368125: 1,
#  368102: 1,
#  367952: 1,
#  367640: 1,
#  367280: 1,
#  367155: 1,
#  367127: 1,
#  367049: 1,
#  367006: 1,
#  366997: 1,
#  366969: 1,
#  366967: 1,
#  366939: 1,
#  366702: 1,
#  366700: 1,
#  366639: 5,
#  366564: 1,
#  366262: 5,
#  366254: 5,
#  366041: 1,
#  366039: 1,
#  365997: 5,
#  365965: 1,
#  365901: 1,
#  365811: 1,
#  365738: 1,
#  365463: 1,
#  365454: 5,
#  365409: 1,
#  365403: 1,
#  365391: 1,
#  365384: 1,
#  365260: 1,
#  365152: 1,
#  364996: 1,
#  364706: 1,
#  364672: 1,
#  364670: 1,
#  364649: 1,
#  364298: 5,
#  364102: 1,
#  364061: 1,
#  364047: 1,
#  364035: 1,
#  363725: 1,
#  363663: 1,
#  363662: 1,
#  363581: 1,
#  363539: 1,
#  363221: 1,
#  363198: 1,
#  363181: 1,
#  363124: 1,
#  363101: 1,
#  363002: 1,
#  362966: 1,
#  362823: 1,
#  362821: 1,
#  362477: 1,
#  362413: 1,
#  362233: 1,
#  362205: 5,
#  362056: 1,
#  362051: 5,
#  362049: 1,
#  362018: 1,
#  362014: 1,
#  361999: 1,
#  361998: 1,
#  361961: 1,
#  361942: 1,
#  361919: 1,
#  361827: 1,
#  361823: 1,
#  361800: 1,
#  361796: 1,
#  361566: 1,
#  361533: 1,
#  361525: 1,
#  361500: 1,
#  361430: 1,
#  361427: 1,
#  361343: 5,
#  361089: 1,
#  361066: 1,
#  361028: 1,
#  360879: 1,
#  360664: 1,
#  360268: 1,
#  360055: 5,
#  359841: 1,
#  359832: 1,
#  359773: 1,
#  359763: 1,
#  359752: 1,
#  359658: 1,
#  359449: 1,
#  359239: 1,
#  358784: 1,
#  358732: 1,
#  358691: 1,
#  358681: 1,
#  358453: 5,
#  358405: 5,
#  358377: 1,
#  358350: 1,
#  358088: 1,
#  358051: 1,
#  358030: 1,
#  358029: 1,
#  357989: 1,
#  357677: 1,
#  357618: 1,
#  357556: 1,
#  357549: 5,
#  357515: 1,
#  357500: 1,
#  357490: 1,
#  357448: 1,
#  357341: 1,
#  357333: 1,
#  357293: 1,
#  357291: 1,
#  357257: 1,
#  357243: 1,
#  357228: 1,
#  357130: 1,
#  356959: 1,
#  356825: 1,
#  356808: 1,
#  356695: 1,
#  356673: 1,
#  356655: 1,
#  356651: 1,
#  356591: 1,
#  356579: 1,
#  356447: 1,
#  356384: 1,
#  356314: 1,
#  356207: 1,
#  355940: 1,
#  355891: 1,
#  355750: 5,
#  355626: 1,
#  355624: 1,
#  355285: 1,
#  355235: 1,
#  355205: 1,
#  355186: 1,
#  355076: 1,
#  355038: 1,
#  355029: 1,
#  355002: 1,
#  354989: 1,
#  354616: 1,
#  354603: 1,
#  354515: 1,
#  354309: 1,
#  354307: 1,
#  354258: 1,
#  354157: 1,
#  354120: 1,
#  354113: 1,
#  354104: 1,
#  354032: 1,
#  353703: 5,
#  353657: 1,
#  353638: 1,
#  353614: 1,
#  353520: 1,
#  353511: 1,
#  353479: 1,
#  353328: 1,
#  353311: 1,
#  353302: 1,
#  353301: 1,
#  353298: 1,
#  353262: 1,
#  353241: 1,
#  353178: 1,
#  353081: 1,
#  353059: 1,
#  353039: 1,
#  353020: 1,
#  352709: 1,
#  352697: 5,
#  352680: 1,
#  352665: 1,
#  352645: 1,
#  352210: 1,
#  352145: 1,
#  352102: 5,
#  352054: 1,
#  351888: 1,
#  351860: 1,
#  351780: 5,
#  351686: 1,
#  351659: 1,
#  351598: 1,
#  351107: 1,
#  351010: 1,
#  350873: 1,
#  350732: 1,
#  350692: 1,
#  350424: 1,
#  350411: 1,
#  350353: 1,
#  350344: 1,
#  350332: 1,
#  350269: 5,
#  350176: 1,
#  350067: 1,
#  350016: 1,
#  349755: 1,
#  349729: 1,
#  349714: 1,
#  349640: 1,
#  349451: 1,
#  349394: 1,
#  349381: 1,
#  349375: 1,
#  349335: 5,
#  349223: 1,
#  349206: 1,
#  349187: 1,
#  349059: 1,
#  349000: 1,
#  348869: 1,
#  348634: 1,
#  348337: 1,
#  348310: 5,
#  348263: 1,
#  348247: 5,
#  347944: 1,
#  347909: 5,
#  347474: 1,
#  347472: 1,
#  347441: 1,
#  347387: 1,
#  347364: 1,
#  347363: 1,
#  347188: 1,
#  347081: 1,
#  347005: 1,
#  346970: 1,
#  346960: 5,
#  346748: 5,
#  346713: 1,
#  346633: 1,
#  346627: 1,
#  346575: 1,
#  346546: 1,
#  346535: 1,
#  346534: 1,
#  346508: 1,
#  346403: 1,
#  346348: 1,
#  346326: 1,
#  346082: 1,
#  346009: 5,
#  345986: 1,
#  345962: 1,
#  345937: 1,
#  345791: 1,
#  345656: 1,
#  345655: 1,
#  345531: 1,
#  345193: 1,
#  345077: 1,
#  345056: 1,
#  344911: 1,
#  344865: 1,
#  344600: 1,
#  344569: 1,
#  344268: 1,
#  344212: 1,
#  344028: 1,
#  344008: 1,
#  343836: 1,
#  343790: 1,
#  343692: 1,
#  343610: 1,
#  343243: 1,
#  342863: 1,
#  342799: 1,
#  342797: 1,
#  342775: 1,
#  342773: 1,
#  342723: 1,
#  342686: 1,
#  342616: 1,
#  342593: 1,
#  342567: 1,
#  342518: 5,
#  342346: 1,
#  342334: 1,
#  342332: 1,
#  342254: 1,
#  342108: 5,
#  342081: 1,
#  342034: 1,
#  341967: 1,
#  341913: 1,
#  341856: 1,
#  341739: 1,
#  341674: 1,
#  341536: 1,
#  341346: 1,
#  341206: 1,
#  341174: 1,
#  340886: 1,
#  340544: 1,
#  340540: 1,
#  340539: 1,
#  340537: 1,
#  340115: 1,
#  340104: 1,
#  339934: 1,
#  339705: 5,
#  339652: 1,
#  339629: 1,
#  339627: 1,
#  339545: 1,
#  339538: 1,
#  339516: 1,
#  339155: 1,
#  339147: 1,
#  339140: 1,
#  339138: 1,
#  338839: 5,
#  338756: 1,
#  338666: 1,
#  338641: 1,
#  338613: 1,
#  338608: 1,
#  338292: 1,
#  337794: 1,
#  337550: 1,
#  337385: 1,
#  337330: 1,
#  336944: 1,
#  336896: 1,
#  336788: 1,
#  336785: 1,
#  336747: 1,
#  336702: 1,
#  336482: 1,
#  336481: 1,
#  336360: 1,
#  336345: 1,
#  336337: 1,
#  336327: 1,
#  335912: 1,
#  335874: 1,
#  335870: 1,
#  335861: 1,
#  335857: 1,
#  335851: 1,
#  335806: 1,
#  335644: 1,
#  335643: 1,
#  335619: 1,
#  335391: 1,
#  335378: 1,
#  335205: 1,
#  335104: 1,
#  335089: 1,
#  335069: 1,
#  335044: 1,
#  334889: 1,
#  334743: 1,
#  334480: 1,
#  334436: 1,
#  334404: 1,
#  334185: 1,
#  334171: 1,
#  333891: 1,
#  333877: 1,
#  333819: 1,
#  333721: 1,
#  333685: 1,
#  333648: 1,
#  333610: 1,
#  333570: 1,
#  333519: 1,
#  333166: 1,
#  333150: 1,
#  333128: 1,
#  333088: 1,
#  333087: 1,
#  333007: 1,
#  332585: 1,
#  332583: 1,
#  332560: 1,
#  332383: 1,
#  332238: 1,
#  332234: 5,
#  332210: 1,
#  332031: 1,
#  331931: 1,
#  331802: 1,
#  331772: 1,
#  331760: 1,
#  331723: 1,
#  331530: 1,
#  331512: 1,
#  331479: 1,
#  331454: 1,
#  331120: 1,
#  331077: 1,
#  331002: 1,
#  330991: 1,
#  330777: 5,
#  330639: 1,
#  330635: 1,
#  330596: 1,
#  330587: 1,
#  330536: 1,
#  330324: 1,
#  330213: 5,
#  330055: 1,
#  330047: 1,
#  329936: 1,
#  329895: 1,
#  329654: 1,
#  329512: 1,
#  329349: 1,
#  329338: 1,
#  329234: 1,
#  329214: 1,
#  329213: 1,
#  328911: 1,
#  328876: 1,
#  328738: 1,
#  328622: 1,
#  328621: 1,
#  328604: 1,
#  328495: 1,
#  328451: 1,
#  328410: 5,
#  328367: 1,
#  328329: 1,
#  328320: 1,
#  328087: 1,
#  327990: 1,
#  327965: 1,
#  327962: 1,
#  327947: 5,
#  327918: 1,
#  327748: 1,
#  327713: 1,
#  327711: 1,
#  327668: 1,
#  327639: 1,
#  327556: 1,
#  327493: 1,
#  327461: 1,
#  327381: 5,
#  327298: 1,
#  327079: 1,
#  326935: 1,
#  326909: 1,
#  326878: 1,
#  326612: 1,
#  326588: 1,
#  326587: 1,
#  326531: 1,
#  326523: 1,
#  326522: 1,
#  326391: 1,
#  326362: 1,
#  326332: 1,
#  326327: 1,
#  326207: 1,
#  326199: 1,
#  326182: 1,
#  326155: 1,
#  325999: 1,
#  325966: 1,
#  325886: 1,
#  325877: 1,
#  325832: 1,
#  325469: 1,
#  325405: 1,
#  325095: 1,
#  325054: 1,
#  324999: 1,
#  324882: 1,
#  324881: 1,
#  324874: 1,
#  324837: 1,
#  324608: 5,
#  324565: 1,
#  324464: 1,
#  324441: 1,
#  324387: 1,
#  324353: 1,
#  324282: 1,
#  324242: 1,
#  324102: 1,
#  324038: 1,
#  323986: 1,
#  323974: 1,
#  323851: 1,
#  323837: 1,
#  323765: 1,
#  323721: 1,
#  323282: 1,
#  323274: 1,
#  323232: 1,
#  323213: 1,
#  322822: 1,
#  322815: 1,
#  322763: 5,
#  322364: 1,
#  322314: 1,
#  322258: 5,
#  322124: 1,
#  322089: 1,
#  322059: 1,
#  321946: 1,
#  321941: 1,
#  321922: 1,
#  321893: 1,
#  321787: 1,
#  321756: 1,
#  321697: 1,
#  321653: 1,
#  321459: 1,
#  321274: 5,
#  321260: 1,
#  321238: 1,
#  321110: 1,
#  321044: 1,
#  321024: 5,
#  320908: 1,
#  320878: 1,
#  320631: 5,
#  320532: 1,
#  320518: 1,
#  320517: 1,
#  320437: 1,
#  320181: 1,
#  320073: 1,
#  320052: 1,
#  319984: 1,
#  319803: 1,
#  319550: 1,
#  319549: 1,
#  319199: 1,
#  319166: 1,
#  319125: 1,
#  319003: 1,
#  319002: 1,
#  318989: 1,
#  318882: 1,
#  318720: 1,
#  318685: 1,
#  318672: 1,
#  318613: 1,
#  318611: 1,
#  318590: 1,
#  318368: 1,
#  318133: 1,
#  317997: 1,
#  317960: 1,
#  317805: 5,
#  317781: 1,
#  317748: 1,
#  317649: 1,
#  317469: 1,
#  317463: 5,
#  317457: 1,
#  317335: 1,
#  317295: 1,
#  317294: 1,
#  317286: 1,
#  317207: 1,
#  317164: 1,
#  317093: 1,
#  317043: 1,
#  316919: 1,
#  316909: 1,
#  316908: 1,
#  316849: 1,
#  316752: 1,
#  316751: 1,
#  316670: 1,
#  316457: 1,
#  316444: 1,
#  316441: 1,
#  316305: 1,
#  315995: 1,
#  315989: 1,
#  315926: 1,
#  315922: 1,
#  315873: 1,
#  315858: 1,
#  315755: 1,
#  315627: 1,
#  315616: 1,
#  315596: 5,
#  315516: 1,
#  315491: 1,
#  315355: 1,
#  315058: 1,
#  314974: 1,
#  314891: 1,
#  314341: 1,
#  314326: 1,
#  314309: 5,
#  314272: 1,
#  314095: 1,
#  314089: 1,
#  314072: 1,
#  314063: 1,
#  314062: 1,
#  313855: 1,
#  313805: 1,
#  313777: 1,
#  313735: 1,
#  313630: 1,
#  313475: 1,
#  313462: 1,
#  313339: 1,
#  313000: 1,
#  312963: 1,
#  312961: 1,
#  312890: 1,
#  312815: 1,
#  312800: 1,
#  312404: 1,
#  312390: 1,
#  312386: 1,
#  312162: 1,
#  312161: 1,
#  312155: 1,
#  312102: 1,
#  311820: 1,
#  311758: 1,
#  311747: 1,
#  311722: 1,
#  311634: 1,
#  311602: 5,
#  311258: 1,
#  311244: 1,
#  310845: 1,
#  310826: 1,
#  310622: 1,
#  310620: 1,
#  310565: 1,
#  310488: 1,
#  310468: 1,
#  310466: 1,
#  310435: 1,
#  310248: 1,
#  310225: 1,
#  310169: 1,
#  310093: 1,
#  310079: 1,
#  309832: 1,
#  309818: 1,
#  309656: 1,
#  309630: 1,
#  309610: 1,
#  309556: 1,
#  309553: 1,
#  309526: 1,
#  309509: 1,
#  309485: 1,
#  309374: 1,
#  309006: 1,
#  309005: 1,
#  308749: 1,
#  308716: 5,
#  308673: 1,
#  308607: 1,
#  308604: 1,
#  308601: 1,
#  308408: 1,
#  308364: 1,
#  308298: 1,
#  308235: 1,
#  308204: 1,
#  308201: 1,
#  308167: 1,
#  308160: 1,
#  308135: 1,
#  308122: 1,
#  308111: 1,
#  308026: 1,
#  308015: 5,
#  307599: 1,
#  307473: 1,
#  307452: 1,
#  307422: 1,
#  307412: 1,
#  307382: 1,
#  307310: 1,
#  307308: 5,
#  307290: 1,
#  307284: 1,
#  307267: 1,
#  307243: 1,
#  307047: 1,
#  306901: 1,
#  306834: 1,
#  306783: 1,
#  306411: 1,
#  306384: 1,
#  306318: 1,
#  306314: 1,
#  306291: 1,
#  306270: 1,
#  306156: 1,
#  306143: 1,
#  305779: 1,
#  305759: 1,
#  305601: 1,
#  305550: 1,
#  305549: 1,
#  305518: 1,
#  305493: 1,
#  305490: 1,
#  305214: 1,
#  305113: 1,
#  305079: 1,
#  305044: 1,
#  305021: 1,
#  304855: 5,
#  304758: 1,
#  304699: 1,
#  304688: 1,
#  304613: 1,
#  304567: 1,
#  304547: 1,
#  304474: 1,
#  304459: 1,
#  304457: 1,
#  304437: 1,
#  304409: 1,
#  304311: 1,
#  304262: 1,
#  304239: 1,
#  304209: 1,
#  304163: 1,
#  304149: 1,
#  303978: 1,
#  303895: 1,
#  303869: 1,
#  303824: 1,
#  303811: 1,
#  303665: 1,
#  303538: 1,
#  303503: 1,
#  303463: 1,
#  303215: 1,
#  303077: 1,
#  303023: 1,
#  303018: 1,
#  302889: 1,
#  302761: 1,
#  302751: 1,
#  302727: 1,
#  302674: 1,
#  302672: 1,
#  302342: 1,
#  302336: 1,
#  302100: 1,
#  302072: 1,
#  301816: 1,
#  301680: 1,
#  301666: 1,
#  301528: 1,
#  301500: 1,
#  301499: 1,
#  301446: 1,
#  301306: 1,
#  301031: 1,
#  300791: 1,
#  300759: 1,
#  300644: 1,
#  300571: 1,
#  300537: 1,
#  300527: 1,
#  300328: 1,
#  300304: 1,
#  300301: 1,
#  299833: 1,
#  299468: 1,
#  299439: 1,
#  299402: 1,
#  299389: 1,
#  299209: 1,
#  299076: 5,
#  299046: 1,
#  298762: 1,
#  298755: 1,
#  298740: 1,
#  298561: 1,
#  298516: 1,
#  298497: 1,
#  298401: 5,
#  298254: 1,
#  298187: 1,
#  298177: 1,
#  298145: 1,
#  298055: 1,
#  298042: 1,
#  298014: 1,
#  297972: 1,
#  297882: 1,
#  297849: 1,
#  297681: 1,
#  297657: 1,
#  297651: 1,
#  297598: 1,
#  297299: 1,
#  297236: 5,
#  297202: 1,
#  297182: 1,
#  297067: 1,
#  296937: 1,
#  296918: 1,
#  296909: 1,
#  296488: 1,
#  296404: 1,
#  296322: 1,
#  296215: 1,
#  296172: 1,
#  296162: 1,
#  296094: 1,
#  295705: 1,
#  295704: 1,
#  295579: 1,
#  295357: 1,
#  295286: 1,
#  295173: 1,
#  295151: 1,
#  295003: 1,
#  294947: 5,
#  294624: 1,
#  294587: 1,
#  294579: 1,
#  293899: 1,
#  293884: 1,
#  293878: 1,
#  293859: 1,
#  293625: 1,
#  ...}

# %%
import agent_code.mcts.deep_network as deep_network
from agent_code.mcts.game_state import state_from_game_state

# %%
import importlib
importlib.reload(deep_network)
# Out:
# <module 'agent_code.mcts.deep_network' from 'g:\\Programming\\bomberman_rl\\agent_code\\mcts\\deep_network.py'>

# %%
import torch_directml
device = torch_directml.device()

# %%
test_network = deep_network.MCTSNetwork().to(device)

# %%
test_network(state_from_game_state(replay.sample(1)[0][0]))
# Out:
# (tensor([[-0.0309]], device='privateuseone:0', grad_fn=<TanhBackward0>),
#  tensor([[0.1987, 0.1115, 0.1903, 0.1209, 0.1654, 0.2131]],
#         device='privateuseone:0', grad_fn=<SoftmaxBackward0>))
